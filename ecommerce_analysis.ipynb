# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("ecommerce_customer_behavior_dataset.csv")

# %%
df.head()
# Out:
#      Order_ID Customer_ID        Date  Age  Gender      City Product_Category  \
# 0  ORD_001337  CUST_01337  2023-01-01   27  Female     Bursa             Toys
# 1  ORD_004885  CUST_04885  2023-01-01   42    Male     Konya             Toys
# 2  ORD_004507  CUST_04507  2023-01-01   43  Female    Ankara             Food
# 3  ORD_000645  CUST_00645  2023-01-01   32    Male  Istanbul      Electronics
# 4  ORD_000690  CUST_00690  2023-01-01   40  Female  Istanbul           Sports
#
#    Unit_Price  Quantity  Discount_Amount  Total_Amount    Payment_Method  \
# 0       54.28         1             0.00         54.28        Debit Card
# 1      244.90         1             0.00        244.90       Credit Card
# 2       48.15         5             0.00        240.75       Credit Card
# 3      804.06         1           229.28        574.78       Credit Card
# 4      755.61         5             0.00       3778.05  Cash on Delivery
#
# ...

# %%
df.tail()
# Out:
#         Order_ID Customer_ID        Date  Age  Gender      City  \
# 4995  ORD_001048  CUST_01048  2024-03-26   18  Female     Izmir
# 4996  ORD_001051  CUST_01051  2024-03-26   27    Male     Adana
# 4997  ORD_003543  CUST_03543  2024-03-26   45  Female   Antalya
# 4998  ORD_004443  CUST_04443  2024-03-26   41  Female  Istanbul
# 4999  ORD_000902  CUST_00902  2024-03-26   30  Female     Konya
#
#      Product_Category  Unit_Price  Quantity  Discount_Amount  Total_Amount  \
# 4995           Beauty      130.35         1            27.30        103.05
# 4996           Beauty       71.55         1             0.00         71.55
# 4997             Food       39.38         1             5.27         34.11
# 4998          Fashion      171.19         1             0.00        171.19
# 4999            Books       84.30         4            21.72        315.48
#
#       Payment_Method Device_Type  Session_Duration_Minutes  Pages_Viewed  \
# ...

# %%
df.shape
# Out:
# (5000, 18)

# %%
print(df.columns)
# Out:
# Index(['Order_ID', 'Customer_ID', 'Date', 'Age', 'Gender', 'City',
#        'Product_Category', 'Unit_Price', 'Quantity', 'Discount_Amount',
#        'Total_Amount', 'Payment_Method', 'Device_Type',
#        'Session_Duration_Minutes', 'Pages_Viewed', 'Is_Returning_Customer',
#        'Delivery_Time_Days', 'Customer_Rating'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Order_ID                  5000 non-null   object
#  1   Customer_ID               5000 non-null   object
#  2   Date                      5000 non-null   object
#  3   Age                       5000 non-null   int64
#  4   Gender                    5000 non-null   object
#  5   City                      5000 non-null   object
#  6   Product_Category          5000 non-null   object
#  7   Unit_Price                5000 non-null   float64
#  8   Quantity                  5000 non-null   int64
#  9   Discount_Amount           5000 non-null   float64
#  10  Total_Amount              5000 non-null   float64
#  11  Payment_Method            5000 non-null   object
#  12  Device_Type               5000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID                    0
# Customer_ID                 0
# Date                        0
# Age                         0
# Gender                      0
# City                        0
# Product_Category            0
# Unit_Price                  0
# Quantity                    0
# Discount_Amount             0
# Total_Amount                0
# Payment_Method              0
# Device_Type                 0
# Session_Duration_Minutes    0
# Pages_Viewed                0
# Is_Returning_Customer       0
# Delivery_Time_Days          0
# Customer_Rating             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                Age   Unit_Price     Quantity  Discount_Amount  Total_Amount  \
# count  5000.000000  5000.000000  5000.000000      5000.000000   5000.000000
# mean     35.032600   455.834120     2.220000        24.852804    983.108914
# std      11.080546   712.477209     1.398711        88.385124   1898.978528
# min      18.000000     5.180000     1.000000         0.000000      7.870000
# 25%      27.000000    76.587500     1.000000         0.000000    122.517500
# 50%      35.000000   182.950000     2.000000         0.000000    337.910000
# 75%      42.000000   513.930000     3.000000         8.760000    979.695000
# max      75.000000  7159.450000     5.000000      1525.550000  22023.900000
#
#        Session_Duration_Minutes  Pages_Viewed  Delivery_Time_Days  \
# count                5000.00000    5000.00000         5000.000000
# mean                   14.57340       8.98420            6.497000
# std                     8.66575       2.80434            3.464966
# ...

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    2492
# Male      2435
# Other       73
# Name: count, dtype: int64

# %%
df["Product_Category"].value_counts()
# Out:
# Product_Category
# Sports           667
# Electronics      624
# Fashion          622
# Beauty           621
# Home & Garden    621
# Food             619
# Books            616
# Toys             610
# Name: count, dtype: int64

# %%
df["Device_Type"].value_counts()
# Out:
# Device_Type
# Mobile     2795
# Desktop    1711
# Tablet      494
# Name: count, dtype: int64

# %%
df["Date"].dtype
# Out:
# dtype('O')

# %%
df["Age"].min(), df["Age"].max()
# Out:
# (18, 75)

# %%
df["Quantity"].min()
# Out:
# 1

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
df["Is_Returning_Customer"].unique()
# Out:
# array([ True, False])

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["Year"] = df["Date"].dt.year

# %%
df["Month"] = df["Date"].dt.month

# %%
df["Month"].value_counts().sort_index()
# Out:
# Month
# 1     659
# 2     641
# 3     632
# 4     281
# 5     355
# 6     349
# 7     342
# 8     371
# 9     306
# 10    361
# 11    336
# 12    367
# Name: count, dtype: int64

# %%
df["Month_Name"] = df["Date"].dt.month_name()

# %%
#Question 1: How much total revenue was generated?
total_revenue = df["Total_Amount"].sum()
total_revenue
# Out:
# np.float64(4915544.57)

# %%
#Question 2: What is the average order value?
average_order = df["Total_Amount"].mean()
average_order
# Out:
# np.float64(983.108914)

# %%
median_order = df["Total_Amount"].median()
median_order
# Out:
# 337.90999999999997

# %%
category_sales = df.groupby("Product_Category")["Total_Amount"].sum()
category_sales
# Out:
# Product_Category
# Beauty            156584.74
# Books              72744.52
# Electronics      2328806.81
# Fashion           375214.93
# Food               96138.67
# Home & Garden     908348.86
# Sports            754563.56
# Toys              223142.48
# Name: Total_Amount, dtype: float64

# %%
category_sales.sort_values(ascending=False)
# Out:
# Product_Category
# Electronics      2328806.81
# Home & Garden     908348.86
# Sports            754563.56
# Fashion           375214.93
# Toys              223142.48
# Beauty            156584.74
# Food               96138.67
# Books              72744.52
# Name: Total_Amount, dtype: float64

# %%
category_quantity = df.groupby("Product_Category")["Quantity"].sum()

category_quantity.sort_values(ascending=False)
# Out:
# Product_Category
# Sports           1519
# Beauty           1424
# Fashion          1411
# Electronics      1379
# Toys             1368
# Food             1355
# Home & Garden    1353
# Books            1291
# Name: Quantity, dtype: int64

# %%
df.groupby("Is_Returning_Customer")["Total_Amount"].agg(
    ["count", "sum", "mean"]
)
# Out:
#                        count         sum        mean
# Is_Returning_Customer
# False                   2010  1967523.73  978.867527
# True                    2990  2948020.84  985.960147

# %%
df.groupby("Device_Type")["Total_Amount"].agg(
    ["count", "sum", "mean"]
).sort_values("sum", ascending=False)
# Out:
#              count         sum         mean
# Device_Type
# Mobile        2795  2810468.64  1005.534397
# Desktop       1711  1650103.78   964.408989
# Tablet         494   454972.15   920.996255

# %%
df.to_csv("ecommerce_cleaned.csv", index=False)

# %%
df[["Session_Duration_Minutes", "Total_Amount"]].corr()
# Out:
#                           Session_Duration_Minutes  Total_Amount
# Session_Duration_Minutes                  1.000000     -0.004119
# Total_Amount                             -0.004119      1.000000

# %%
df[["Session_Duration_Minutes", "Pages_Viewed"]].corr()
# Out:
#                           Session_Duration_Minutes  Pages_Viewed
# Session_Duration_Minutes                  1.000000      0.023923
# Pages_Viewed                              0.023923      1.000000

# %%
df[["Pages_Viewed", "Total_Amount"]].corr()
# Out:
#               Pages_Viewed  Total_Amount
# Pages_Viewed      1.000000     -0.011831
# Total_Amount     -0.011831      1.000000

# %%
df.groupby("Is_Returning_Customer")["Total_Amount"].mean()
# Out:
# Is_Returning_Customer
# False    978.867527
# True     985.960147
# Name: Total_Amount, dtype: float64

# %%
df.groupby("Is_Returning_Customer")["Quantity"].mean()
# Out:
# Is_Returning_Customer
# False    2.212438
# True     2.225084
# Name: Quantity, dtype: float64

# %%
df[["Delivery_Time_Days", "Customer_Rating"]].corr()
# Out:
#                     Delivery_Time_Days  Customer_Rating
# Delivery_Time_Days            1.000000        -0.009948
# Customer_Rating              -0.009948         1.000000

# %%
df.groupby("Delivery_Time_Days")["Customer_Rating"].mean()
# Out:
# Delivery_Time_Days
# 1     3.632353
# 2     3.862687
# 3     4.040780
# 4     3.911628
# 5     3.887725
# 6     3.859016
# 7     3.894325
# 8     3.952020
# 9     3.856707
# 10    3.928571
# 11    3.869159
# 12    3.848276
# 13    3.840909
# 14    3.809524
# 15    4.021739
# 16    3.840000
# 17    3.952381
# 18    3.944444
# 19    3.777778
# 20    4.000000
# 21    4.666667
# 22    3.666667
# 23    3.666667
# 24    4.000000
# 25    3.500000
# Name: Customer_Rating, dtype: float64

# %%
df[["Discount_Amount", "Quantity"]].corr()
# Out:
#                  Discount_Amount  Quantity
# Discount_Amount         1.000000  0.014404
# Quantity                0.014404  1.000000

# %%
df[["Discount_Amount", "Total_Amount"]].corr()
# Out:
#                  Discount_Amount  Total_Amount
# Discount_Amount         1.000000      0.347578
# Total_Amount            0.347578      1.000000

# %%
df["Age"].describe()
# Out:
# count    5000.000000
# mean       35.032600
# std        11.080546
# min        18.000000
# 25%        27.000000
# 50%        35.000000
# 75%        42.000000
# max        75.000000
# Name: Age, dtype: float64

# %%
df["Age_Group"] = pd.cut(
    df["Age"],
    bins=[17, 25, 35, 45, 55, 75],
    labels=["18-25", "26-35", "36-45", "46-55", "56+"]
)

# %%
df.groupby("Age_Group", observed=True)["Total_Amount"].agg(
    ["count", "sum", "mean"]
)
# Out:
#            count         sum         mean
# Age_Group
# 18-25       1125  1144430.40  1017.271467
# 26-35       1514  1436643.56   948.905918
# 36-45       1470  1480389.66  1007.067796
# 46-55        697   673097.85   965.707102
# 56+          194   180983.10   932.902577

# %%
numeric_columns = [
    "Age",
    "Unit_Price",
    "Quantity",
    "Discount_Amount",
    "Total_Amount",
    "Session_Duration_Minutes",
    "Pages_Viewed",
    "Delivery_Time_Days",
    "Customer_Rating"
]

correlation_matrix = df[numeric_columns].corr()

correlation_matrix
# Out:
#                                Age  Unit_Price  Quantity  Discount_Amount  \
# Age                       1.000000   -0.001618  0.000131        -0.012163
# Unit_Price               -0.001618    1.000000 -0.004005         0.449766
# Quantity                  0.000131   -0.004005  1.000000         0.014404
# Discount_Amount          -0.012163    0.449766  0.014404         1.000000
# Total_Amount             -0.004473    0.791073  0.329053         0.347578
# Session_Duration_Minutes  0.001897   -0.010063 -0.006383        -0.001656
# Pages_Viewed             -0.006434    0.004763 -0.004417         0.009103
# Delivery_Time_Days       -0.017105   -0.005888 -0.004569        -0.019653
# Customer_Rating          -0.010401    0.006185 -0.015598         0.013526
#
#                           Total_Amount  Session_Duration_Minutes  \
# Age                          -0.004473                  0.001897
# Unit_Price                    0.791073                 -0.010063
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
category_sales = df.groupby("Product_Category")["Total_Amount"].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))

category_sales.plot(kind="bar")

plt.title("Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
monthly_revenue = df.groupby("Month")["Total_Amount"].sum()

# %%
monthly_revenue = df.groupby("Month")["Total_Amount"].sum()

plt.figure(figsize=(10, 6))

monthly_revenue.plot(kind="line", marker="o")

plt.title("Monthly Revenue")
plt.xlabel("Month")
plt.ylabel("Total Revenue")
plt.xticks(range(1, 13))
plt.grid(True)
plt.tight_layout()

plt.savefig("images/monthly_revenue.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
customer_type = df.groupby("Is_Returning_Customer")["Total_Amount"].mean()

plt.figure(figsize=(8, 5))

customer_type.plot(kind="bar")

plt.title("Average Order Value: Returning vs New Customers")
plt.xlabel("Returning Customer")
plt.ylabel("Average Order Value")
plt.xticks(rotation=0)
plt.tight_layout()

plt.savefig("images/customer_type.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
device_revenue = (
    df.groupby("Device_Type")["Total_Amount"]
    .sum()
    .sort_values(ascending=False)
)

plt.figure(figsize=(8, 5))

device_revenue.plot(kind="bar")

plt.title("Revenue by Device Type")
plt.xlabel("Device Type")
plt.ylabel("Total Revenue")
plt.tight_layout()

plt.savefig("images/device_revenue.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Delivery_Time_Days",
    y="Customer_Rating"
)

plt.title("Delivery Time vs Customer Rating")
plt.xlabel("Delivery Time (Days)")
plt.ylabel("Customer Rating")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Session_Duration_Minutes",
    y="Total_Amount"
)

plt.title("Session Duration vs Total Spending")
plt.xlabel("Session Duration (Minutes)")
plt.ylabel("Total Amount")

plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

plt.title("Correlation Matrix of Numerical Variables")
plt.tight_layout()

plt.savefig("images/correlation_heatmap.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
category_sales = df.groupby("Product_Category")["Total_Amount"].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))

category_sales.plot(kind="bar")

plt.title("Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig("images/revenue_by_category.png", dpi=300, bbox_inches="tight")

plt.show()
